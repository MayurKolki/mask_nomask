# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import cv2

# %%
taj = cv2.imread(r"D:\imarticus\Computer Vission\images\taj.jpg")

# %%
taj.shape
# Out:
# (359, 467, 3)

# %%
plt.imshow(taj)

# %%
correct_f = cv2.cvtColor(taj , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(correct_f)

# %% [markdown]
# ### Open CV mai default hai BGR

# %%
taj_grey = cv2.imread(r"D:\imarticus\Computer Vission\images\taj.jpg" , cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(taj_grey)

# %%
plt.imshow(taj_grey , cmap='gray')

# %%
## Lets reshape the image
taj_resize = cv2.resize(taj , (100 , 200))
print(taj_resize.shape)
# Out:
# (200, 100, 3)

# %%
plt.imshow(taj_resize)

# %%
train = cv2.imread(r"D:\imarticus\Computer Vission\images\Train7.PNG")

# %%
plt.imshow(train)

# %%
plt.imshow(cv2.flip(train , 0)) # vertically flip.

# %%
plt.imshow(cv2.flip(train , 1)) # flip

# %%
plt.imshow(cv2.flip(train , -1)) # both horizantal and vertical flip

# %%
plt.imshow(cv2.flip(train , -4))

# %%
cv2.imshow('train_img' , train)

# %%
while True:
    cv2.imshow('train_image' , train)
    if cv2.waitKey() & 0xff ==27:
        ok_flag = False
        break
        
    cv2.destroyAllWindows()

# %%
from PIL import Image as im

# %%
pic1 = im.open(r"D:\imarticus\Computer Vission\images\Train7.PNG")
type(pic1)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
plt.imshow(pic1)

# %%
type(train)
# Out:
# numpy.ndarray

# %%
pic1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=541x419 at 0x2911799A248>

# %%
pic2 = np.array(pic1) # Convert PNGIMAGE TO NUMBER array

# %%
pic2.shape
# Out:
# (419, 541, 4)

# %%
train.shape
# Out:
# (419, 541, 3)

# %%
plt.imshow(pic2)

# %%
plt.imshow(pic2[:,: , 1]) # using green channel

# %%
plt.imshow(pic2[:,: , 0]) # Using only red channel

# %%
plt.imshow(pic2[:,: , 2]) # using blue channel

# %%
plt.imshow(taj[:,:,0])

# %%
plt.imshow(taj[:,:,1])

# %%
plt.imshow(taj[:,:,2])

# %%
# Lets remove the channels
pic2[:,:,0] = 0 # removing the red channel
plt.imshow(pic2)

# %%
# Lets remove the channels
pic2[:,:,1] = 0 # removing the green channel
plt.imshow(pic2)

# %%
# Lets remove the channels
pic2[:,:,2] = 0 # removing the blue channel
plt.imshow(pic2)

# %%
# No we cant get black and white color after removing all channels.

# %%
pic2.shape
# Out:
# (419, 541, 4)

# %%
plt.imshow(pic2)
